# %%
import numpy as np
import pandas as pd

A = [0,3,2,5]
B = [0,3,1,4]

sum = np.add(A, B)
sub = np.subtract(A, B)
aScaled = np.multiply(A, 4)
dotProd = np.dot(A, B)
bSize = np.size(B)

print("Sum = ", sum)
print("Subtract = ", sub)
print("A multiplied by 4 = ", aScaled)
print("Dot product = ", dotProd)
print("B size = ", bSize)
# Out:
# Sum =  [0 6 3 9]
# Subtract =  [0 0 1 1]
# A multiplied by 4 =  [ 0 12  8 20]
# Dot product =  31
# B size =  4
